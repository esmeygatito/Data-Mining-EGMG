# %%
import requests
import pandas as pd
from datetime import date
from urllib.parse import quote_plus
import time

# %%
##FUENTE : https://opendata.nhsbsa.net/dataset/english-prescribing-dataset-epd-with-snomed-code/resource/004d6f4e-9881-4312-82dc-094f9a543885

# %%
BASE_URL = "https://opendata.nhsbsa.net/api/3/action/datastore_search_sql?"
sustancias = ["Semaglutide", "Liraglutide", "Dulaglutide", "Exenatide", "Lixisenatide", "Tirzepatide"] #sustancias a buscar

# %%
#ver el contenido de la API para ver los nombres de los recursos    
package_url = "https://opendata.nhsbsa.net/api/3/action/package_show?id=english-prescribing-dataset-epd-with-snomed-code"
resp = requests.get(package_url)
resp.raise_for_status()
data = resp.json()

for resource in data['result']['resources']:
    print(resource['name'])
# Out:
# EPD_SNOMED_202011
# EPD_SNOMED_202012
# EPD_SNOMED_202101
# EPD_SNOMED_202102
# EPD_SNOMED_202103
# EPD_SNOMED_202104
# EPD_SNOMED_202105
# EPD_SNOMED_202106
# EPD_SNOMED_202107
# EPD_SNOMED_202108
# EPD_SNOMED_202109
# EPD_SNOMED_202110
# EPD_SNOMED_202111
# EPD_SNOMED_202112
# EPD_SNOMED_202201
# EPD_SNOMED_202202
# EPD_SNOMED_202203
# EPD_SNOMED_202204
# EPD_SNOMED_202205
# EPD_SNOMED_202206
# EPD_SNOMED_202207
# EPD_SNOMED_202208
# EPD_SNOMED_202209
# EPD_SNOMED_202210
# EPD_SNOMED_202211
# EPD_SNOMED_202212
# EPD_SNOMED_202301
# EPD_SNOMED_202302
# EPD_SNOMED_202303
# EPD_SNOMED_202304
# EPD_SNOMED_202305
# EPD_SNOMED_202306
# EPD_SNOMED_202307
# EPD_SNOMED_202308
# EPD_SNOMED_202309
# EPD_SNOMED_202310
# EPD_SNOMED_202311
# EPD_SNOMED_202312
# EPD_SNOMED_202401
# EPD_SNOMED_202402
# EPD_SNOMED_202403
# EPD_SNOMED_202404
# EPD_SNOMED_202405
# EPD_SNOMED_202406
# EPD_SNOMED_202407
# EPD_SNOMED_202408
# EPD_SNOMED_202409
# EPD_SNOMED_202410
# EPD_SNOMED_202411
# EPD_SNOMED_202412
# EPD_SNOMED_202501
# EPD_SNOMED_202502
# EPD_SNOMED_202503
# EPD_SNOMED_202504
# EPD_SNOMED_202505
# EPD_SNOMED_202506
# EPD_SNOMED_202507
# EPD_SNOMED_202508
# EPD_SNOMED_202509
# EPD_SNOMED_202510
# EPD_SNOMED_202511
# EPD_SNOMED_202512
# EPD_SNOMED_202601
# EPD_SNOMED_202602
# EPD_SNOMED_202603
# EPD_SNOMED_202604
# EPD_SNOMED_202605

# %%
print(j.get('result')) #revisar que el recurso que queremos está en la lista de recursos
# Out:
# {'help': 'https://demo.ckan.org/api/3/action/help_show?name=datastore_search_sql', 'success': 'true', 'result': {'records': [{'YEAR_MONTH': 202101, 'REGIONAL_OFFICE_NAME': 'MIDLANDS', 'REGIONAL_OFFICE_CODE': 'Y60', 'STP_NAME': 'COVENTRY & WARWICKSHIRE STP', 'STP_CODE': 'QWU', 'PCO_NAME': 'COVENTRY AND RUGBY CCG', 'PCO_CODE': '05A00', 'PRACTICE_NAME': 'SPRINGFIELD MEDICAL PRACTICE', 'PRACTICE_CODE': 'M86021', 'ADDRESS_1': 'SPRINGFIELD MED PRACTICE', 'ADDRESS_2': 'BENNETTS ROAD SOUTH', 'ADDRESS_3': 'KERESLEY', 'ADDRESS_4': 'COVENTRY', 'POSTCODE': 'CV6 2FL', 'BNF_CHEMICAL_SUBSTANCE': '0601023AW', 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Semaglutide', 'BNF_CODE': '0601023AWBBABAB', 'BNF_DESCRIPTION': 'Ozempic 0.5mg/0.37ml inj 1.5ml pre-filled pens', 'BNF_CHAPTER_PLUS_CODE': '06: Endocrine System', 'QUANTITY': 1, 'ITEMS': 1, 'TOTAL_QUANTITY': 1, 'ADQUSAGE': 0, 'NIC': 73.25, 'ACTUAL_COST': 68.18987, 'UNIDENTIFIED': 'N', 'SNOMED_CODE': '36471111000001106'}, {'YEAR_MONTH': 202101, 'REGIONAL_OFFICE_NAME': 'MIDLANDS', 'REGIONAL_OFFICE_CODE': 'Y60', 'STP_NAME': 'HEREFORDSHIRE & WORCESTERSHIRE STP', 'STP_CODE': 'QGH', 'PCO_NAME': 'HEREFORDSHIRE AND WORCESTERSHIRE CCG', 'PCO_CODE': '18C00', 'PRACTICE_NAME': 'NUNWELL SURGERY', 'PRACTICE_CODE': 'M81048', 'ADDRESS_1': 'NUNWELL SURGERY', 'ADDRESS_2': '10 PUMP STREET', 'ADDRESS_3': 'BROMYARD', 'ADDRESS_4': 'HEREFORDSHIRE', 'POSTCODE': 'HR7 4BZ', 'BNF_CHEMICAL_SUBSTANCE': '0601023AW', 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Semaglutide', 'BNF_CODE': '0601023AWBBACAC', 'BNF_DESCRIPTION': 'Ozempic 1mg/0.74ml inj 3ml pre-filled pens', 'BNF_CHAPTER_PLUS_CODE': '06: Endocrine System', 'QUANTITY': 1, 'ITEMS': 1, 'TOTAL_QUANTITY': 1, 'ADQUSAGE': 0, 'NIC': 73.25, 'ACTUAL_COST': 68.17747, 'UNIDENTIFIED': 'N', 'SNOMED_CODE': '36471411000001101'}, {'YEAR_MONTH': 202101, 'REGIONAL_OFFICE_NAME': 'LONDON', 'REGIONAL_OFFICE_CODE': 'Y56', 'STP_NAME': 'EAST LONDON HEALTH & CARE P/SHIP STP', 'STP_CODE': 'QMF', 'PCO_NAME': 'REDBRIDGE CCG', 'PCO_CODE': '08N00', 'PRACTICE_NAME': 'THE PALMS MEDICAL CENTRE', 'PRACTICE_CODE': 'F86009', 'ADDRESS_1': 'THE PALMS MEDICAL CENTRE', 'ADDRESS_2': '97-101 NETLEY ROAD', 'ADDRESS_3': 'NEWBURY PARK', 'ADDRESS_4': 'ILFORD, ESSEX', 'POSTCODE': 'IG2 7NW', 'BNF_CHEMICAL_SUBSTANCE': '0601023AW', 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Semaglutide', 'BNF_CODE': '0601023AWAAACAC', 'BNF_DESCRIPTION': 'Semaglutide 1mg/0.74ml inj 3ml pre-filled disposable device', 'BNF_CHAPTER_PLUS_CODE': '06: Endocrine System', 'QUANTITY': 4, 'ITEMS': 1, 'TOTAL_QUANTITY': 4, 'ADQUSAGE': 0, 'NIC': 293, 'ACTUAL_COST': 272.7223, 'UNIDENTIFIED': 'N', 'SNOMED_CODE': '36491111000001100'}, {'YEAR_MONTH': 202101, 'REGIONAL_OFFICE_NAME': 'NORTH WEST', 'REGIONAL_OFFICE_CODE': 'Y62', 'STP_NAME': 'GREATER MANCHESTER HSC PARTNERSHIP STP', 'STP_CODE': 'QOP', 'PCO_NAME': 'MANCHESTER CCG', 'PCO_CODE': '14L00', 'PRACTICE_NAME': 'VALENTINE MEDICAL CENTRE', 'PRACTICE_CODE': 'P84019', 'ADDRESS_1': 'VALENTINE MEDICAL CENTRE', 'ADDRESS_2': '2 SMETHURST ST, BLACKLEY', 'ADDRESS_3': 'MANCHESTER', 'ADDRESS_4': 'GREATER MANCHESTER', 'POSTCODE': 'M9 8PP', 'BNF_CHEMICAL_SUBSTANCE': '0601023AW', 'CHEMICAL_SUBSTANCE_BNF_DESCR': 'Semaglutide', 'BNF_CODE': '0601023AWAAACAC', 'BNF_DESCRIPTION': 'Semaglutide 1mg/0.74ml inj 3ml pre-filled disposable device', 'BNF_CHAPTER_PLUS_CODE': '06: Endocrine System', 'QUANTITY': 2, 'ITEMS': 1, 'TOTAL_QUANTITY': 2, 'ADQUSAGE': 0, 'NIC': 146.5, 'ACTUAL_COST': 136.36735, 'UNIDENTIFIED': 'N', 'SNOMED_CODE': '36491111000001100'}, {'YEAR_MONTH': 202101, 'REGIONAL_OFFICE_NAME': 'MIDLANDS', 'REGIONAL_OFFICE_CODE': 'Y60', 'STP_NAME': 'BIRMINGHAM & SOLIHULL STP', 'STP_CODE': 'QHL', 'PCO_NAME': 'BIRMINGHAM AND SOLIHULL CCG', 'PCO_CODE': '15E00', 'PRACTICE_NAME': 'CAVENDISH MEDICAL PRACTICE', 'PRACTICE_CODE': 'M85642', 'ADDRESS_1': 'SUMMERFIELD P\\C CENTRE', 'ADDRESS_2': '134 HEATH ST,WINSON GREEN', 'ADDRESS_3': 'BIRMINGHAM', 'ADDRESS_4': '', 'POSTCODE': 'B18 7AL', 'BNF_CHEMICAL_SUBSTANCE': '0601023AW', 'CHEMICAL_SUBSTANCE_BNF_DESCR':  ...

# %%
fechas = pd.date_range(start='2021-01-01', end=pd.Timestamp.today(), freq='MS')
print(fechas) #fechas en que se va a buscar la información
# Out:
# DatetimeIndex(['2021-01-01', '2021-02-01', '2021-03-01', '2021-04-01',
#                '2021-05-01', '2021-06-01', '2021-07-01', '2021-08-01',
#                '2021-09-01', '2021-10-01', '2021-11-01', '2021-12-01',
#                '2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01', '2023-02-01', '2023-03-01', '2023-04-01',
#                '2023-05-01', '2023-06-01', '2023-07-01', '2023-08-01',
#                '2023-09-01', '2023-10-01', '2023-11-01', '2023-12-01',
#                '2024-01-01', '2024-02-01', '2024-03-01', '2024-04-01',
#                '2024-05-01', '2024-06-01', '2024-07-01', '2024-08-01',
#                '2024-09-01', '2024-10-01', '2024-11-01', '2024-12-01',
#                '2025-01-01', '2025-02-01', '2025-03-01', '2025-04-01',
#                '2025-05-01', '2025-06-01', '2025-07-01', '2025-08-01',
#                '2025-09-01', '2025-10-01', '2025-11-01', '2025-12-01',
#                '2026-01-01', '2026-02-01', '2026-03-01', '2026-04-01',
#                '2026-05-01', '2026-06-01', '2026-07-01', '2026-08-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
meses = [f.strftime('%Y%m') for f in fechas] #formato de fechas para buscar en la API

# %%
def extraer_records(j): #función para extraer los registros de la respuesta de la API
    nivel1 = j.get('result', {})
    if 'records' in nivel1:
        return nivel1['records']
    else:
        nivel2 = nivel1.get('result', {})
        return nivel2.get('records', [])

# %%
resultados = [] #primer ciclo para recorrer los meses y el segundo para recorrer las sustancias y lograr extraer la información de la API

for mes in meses:
    for sustancia in sustancias:
        resource_id = f"EPD_SNOMED_{mes}"
        sql = f"""SELECT * FROM `{resource_id}` where CHEMICAL_SUBSTANCE_BNF_DESCR = '{sustancia}'"""

        try:
            r = requests.get(
                BASE_URL,
                params={
                    'resource_id': resource_id,
                    'sql': sql
                },
                timeout=60
            )
            print('HTTP status:', r.status_code)
            j = r.json()
            records = extraer_records(j)
            print('Registros devueltos:', len(records))
            time.sleep(0.3)
            if records:
                df = pd.DataFrame(records)
                resultados.append(df)   
            else:
                print('Error:', j.get('error'))
        except Exception as e:
            print('Error en la petición:', e)
# Out:
# HTTP status: 200
# Registros devueltos: 13722
# HTTP status: 200
# Registros devueltos: 16063
# HTTP status: 200
# Registros devueltos: 15637
# HTTP status: 200
# Registros devueltos: 4522
# HTTP status: 200
# Registros devueltos: 1554
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 13893
# HTTP status: 200
# Registros devueltos: 15608
# HTTP status: 200
# Registros devueltos: 15674
# HTTP status: 200
# Registros devueltos: 4383
# HTTP status: 200
# Registros devueltos: 1448
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 15575
# HTTP status: 200
# Registros devueltos: 16165
# HTTP status: 200
# Registros devueltos: 16542
# HTTP status: 200
# Registros devueltos: 4496
# HTTP status: 200
# Registros devueltos: 1488
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 16111
# HTTP status: 200
# Registros devueltos: 15913
# HTTP status: 200
# Registros devueltos: 16933
# HTTP status: 200
# Registros devueltos: 4236
# HTTP status: 200
# Registros devueltos: 1452
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 16637
# HTTP status: 200
# Registros devueltos: 15394
# HTTP status: 200
# Registros devueltos: 17299
# HTTP status: 200
# Registros devueltos: 4094
# HTTP status: 200
# Registros devueltos: 1427
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 17848
# HTTP status: 200
# Registros devueltos: 15896
# HTTP status: 200
# Registros devueltos: 18359
# HTTP status: 200
# Registros devueltos: 4130
# HTTP status: 200
# Registros devueltos: 1427
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 18701
# HTTP status: 200
# Registros devueltos: 15474
# HTTP status: 200
# Registros devueltos: 19044
# HTTP status: 200
# Registros devueltos: 4066
# HTTP status: 200
# Registros devueltos: 1387
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 18800
# HTTP status: 200
# Registros devueltos: 14931
# HTTP status: 200
# Registros devueltos: 19194
# HTTP status: 200
# Registros devueltos: 3721
# HTTP status: 200
# Registros devueltos: 1326
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 19655
# HTTP status: 200
# Registros devueltos: 15083
# HTTP status: 200
# Registros devueltos: 19979
# HTTP status: 200
# Registros devueltos: 3840
# HTTP status: 200
# Registros devueltos: 1304
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 19896
# HTTP status: 200
# Registros devueltos: 14719
# HTTP status: 200
# Registros devueltos: 20104
# HTTP status: 200
# Registros devueltos: 3559
# HTTP status: 200
# Registros devueltos: 1241
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 20999
# HTTP status: 200
# Registros devueltos: 14790
# HTTP status: 200
# Registros devueltos: 21020
# HTTP status: 200
# Registros devueltos: 3501
# HTTP status: 200
# Registros devueltos: 1229
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 21798
# HTTP status: 200
# Registros devueltos: 14924
# HTTP status: 200
# Registros devueltos: 21747
# HTTP status: 200
# Registros devueltos: 3488
# HTTP status: 200
# Registros devueltos: 1206
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 22039
# HTTP status: 200
# Registros devueltos: 14404
# HTTP status: 200
# Registros devueltos: 21815
# HTTP status: 200
# Registros devueltos: 3297
# HTTP status: 200
# Registros devueltos: 1186
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 22494
# HTTP status: 200
# Registros devueltos: 13837
# HTTP status: 200
# Registros devueltos: 21012
# HTTP status: 200
# Registros devueltos: 3123
# HTTP status: 200
# Registros devueltos: 1110
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 24790
# HTTP status: 200
# Registros devueltos: 14534
# HTTP status: 200
# Registros devueltos: 21545
# HTTP status: 200
# Registros devueltos: 3252
# HTTP status: 200
# Registros devueltos: 1159
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 24683
# HTTP status: 200
# Registros devueltos: 14015
# HTTP status: 200
# Registros devueltos: 23209
# HTTP status: 200
# Registros devueltos: 3093
# HTTP status: 200
# Registros devueltos: 1092
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 25764
# HTTP status: 200
# Registros devueltos: 14134
# HTTP status: 200
# Registros devueltos: 23488
# HTTP status: 200
# Registros devueltos: 3101
# HTTP status: 200
# Registros devueltos: 1054
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 26223
# HTTP status: 200
# Registros devueltos: 13846
# HTTP status: 200
# Registros devueltos: 23777
# HTTP status: 200
# Registros devueltos: 2937
# HTTP status: 200
# Registros devueltos: 991
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 26240
# HTTP status: 200
# Registros devueltos: 13650
# HTTP status: 200
# Registros devueltos: 24310
# HTTP status: 200
# Registros devueltos: 2865
# HTTP status: 200
# Registros devueltos: 989
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 27724
# HTTP status: 200
# Registros devueltos: 13724
# HTTP status: 200
# Registros devueltos: 24845
# HTTP status: 200
# Registros devueltos: 2841
# HTTP status: 200
# Registros devueltos: 937
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 28163
# HTTP status: 200
# Registros devueltos: 13449
# HTTP status: 200
# Registros devueltos: 25240
# HTTP status: 200
# Registros devueltos: 2759
# HTTP status: 200
# Registros devueltos: 928
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 31911
# HTTP status: 200
# Registros devueltos: 13528
# HTTP status: 200
# Registros devueltos: 25316
# HTTP status: 200
# Registros devueltos: 2819
# HTTP status: 200
# Registros devueltos: 886
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 31465
# HTTP status: 200
# Registros devueltos: 13807
# HTTP status: 200
# Registros devueltos: 25396
# HTTP status: 200
# Registros devueltos: 2819
# HTTP status: 200
# Registros devueltos: 860
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 14021
# HTTP status: 200
# Registros devueltos: 25487
# HTTP status: 200
# Registros devueltos: 2861
# HTTP status: 200
# Registros devueltos: 841
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 13953
# HTTP status: 200
# Registros devueltos: 25610
# HTTP status: 200
# Registros devueltos: 2734
# HTTP status: 200
# Registros devueltos: 821
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 13486
# HTTP status: 200
# Registros devueltos: 25135
# HTTP status: 200
# Registros devueltos: 2589
# HTTP status: 200
# Registros devueltos: 786
# HTTP status: 200
# Registros devueltos: 1
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 14347
# HTTP status: 200
# Registros devueltos: 26345
# HTTP status: 200
# Registros devueltos: 2753
# HTTP status: 200
# Registros devueltos: 766
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 13885
# HTTP status: 200
# Registros devueltos: 25648
# HTTP status: 200
# Registros devueltos: 2598
# HTTP status: 200
# Registros devueltos: 707
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 14276
# HTTP status: 200
# Registros devueltos: 26596
# HTTP status: 200
# Registros devueltos: 2762
# HTTP status: 200
# Registros devueltos: 756
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 14048
# HTTP status: 200
# Registros devueltos: 27174
# HTTP status: 200
# Registros devueltos: 2984
# HTTP status: 200
# Registros devueltos: 721
# HTTP status: 200
# Registros devueltos: 1
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 14249
# HTTP status: 200
# Registros devueltos: 27331
# HTTP status: 200
# Registros devueltos: 3189
# HTTP status: 200
# Registros devueltos: 740
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 12418
# HTTP status: 200
# Registros devueltos: 27032
# HTTP status: 200
# Registros devueltos: 3164
# HTTP status: 200
# Registros devueltos: 706
# HTTP status: 200
# Registros devueltos: 1
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 12007
# HTTP status: 200
# Registros devueltos: 26769
# HTTP status: 200
# Registros devueltos: 3040
# HTTP status: 200
# Registros devueltos: 681
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 8868
# HTTP status: 200
# Registros devueltos: 26562
# HTTP status: 200
# Registros devueltos: 3002
# HTTP status: 200
# Registros devueltos: 673
# HTTP status: 200
# Registros devueltos: 1
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 6610
# HTTP status: 200
# Registros devueltos: 26800
# HTTP status: 200
# Registros devueltos: 2951
# HTTP status: 200
# Registros devueltos: 643
# HTTP status: 200
# Registros devueltos: 2
# HTTP status: 200
# Registros devueltos: 31190
# HTTP status: 200
# Registros devueltos: 5284
# HTTP status: 200
# Registros devueltos: 26255
# HTTP status: 200
# Registros devueltos: 2764
# HTTP status: 200
# Registros devueltos: 472
# HTTP status: 200
# Registros devueltos: 3
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 4288
# HTTP status: 200
# Registros devueltos: 25783
# HTTP status: 200
# Registros devueltos: 2728
# HTTP status: 200
# Registros devueltos: 280
# HTTP status: 200
# Registros devueltos: 5
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 3390
# HTTP status: 200
# Registros devueltos: 25064
# HTTP status: 200
# Registros devueltos: 2476
# HTTP status: 200
# Registros devueltos: 198
# HTTP status: 200
# Registros devueltos: 198
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 2708
# HTTP status: 200
# Registros devueltos: 24525
# HTTP status: 200
# Registros devueltos: 2531
# HTTP status: 200
# Registros devueltos: 151
# HTTP status: 200
# Registros devueltos: 1681
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 2248
# HTTP status: 200
# Registros devueltos: 24721
# HTTP status: 200
# Registros devueltos: 2388
# HTTP status: 200
# Registros devueltos: 105
# HTTP status: 200
# Registros devueltos: 5090
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 1838
# HTTP status: 200
# Registros devueltos: 23358
# HTTP status: 200
# Registros devueltos: 2366
# HTTP status: 200
# Registros devueltos: 80
# HTTP status: 200
# Registros devueltos: 8871
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 1565
# HTTP status: 200
# Registros devueltos: 22920
# HTTP status: 200
# Registros devueltos: 2187
# HTTP status: 200
# Registros devueltos: 60
# HTTP status: 200
# Registros devueltos: 12218
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 1322
# HTTP status: 200
# Registros devueltos: 22804
# HTTP status: 200
# Registros devueltos: 2142
# HTTP status: 200
# Registros devueltos: 35
# HTTP status: 200
# Registros devueltos: 16075
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 1082
# HTTP status: 200
# Registros devueltos: 20937
# HTTP status: 200
# Registros devueltos: 2077
# HTTP status: 200
# Registros devueltos: 22
# HTTP status: 200
# Registros devueltos: 18774
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 914
# HTTP status: 200
# Registros devueltos: 19851
# HTTP status: 200
# Registros devueltos: 1924
# HTTP status: 200
# Registros devueltos: 13
# HTTP status: 200
# Registros devueltos: 21329
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 842
# HTTP status: 200
# Registros devueltos: 20316
# HTTP status: 200
# Registros devueltos: 1842
# HTTP status: 200
# Registros devueltos: 11
# HTTP status: 200
# Registros devueltos: 24747
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 733
# HTTP status: 200
# Registros devueltos: 19624
# HTTP status: 200
# Registros devueltos: 1739
# HTTP status: 200
# Registros devueltos: 8
# HTTP status: 200
# Registros devueltos: 27088
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 685
# HTTP status: 200
# Registros devueltos: 19339
# HTTP status: 200
# Registros devueltos: 1688
# HTTP status: 200
# Registros devueltos: 6
# HTTP status: 200
# Registros devueltos: 28940
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 698
# HTTP status: 200
# Registros devueltos: 19207
# HTTP status: 200
# Registros devueltos: 1642
# HTTP status: 200
# Registros devueltos: 6
# HTTP status: 200
# Registros devueltos: 31622
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 200
# Registros devueltos: 620
# HTTP status: 200
# Registros devueltos: 18362
# HTTP status: 200
# Registros devueltos: 1509
# HTTP status: 200
# Registros devueltos: 10
# HTTP status: 200
# Registros devueltos: 0
# Error: None
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# Error en la petición: HTTPSConnectionPool(host='opendata.nhsbsa.net', port=443): Read timed out. (read timeout=60)
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 500
# Registros devueltos: 0
# Error: {'__type': 'Internal Server Error', 'message': 'Internal Server Error'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}
# HTTP status: 404
# Registros devueltos: 0
# Error: {'__type': 'Not Found Error', 'message': 'Not found'}

# %%
print(len(resultados)) #verificar que se hayan extraído los datos de todos los meses y sustancias  (no necesariamente todos los meses tienen datos para todas las sustancias)
# Out:
# 243

# %%
combinaciones_totales = len(meses) * len(sustancias) #noto que me faltan combinaciones de meses y sustancias, por lo que calculo el total de combinaciones posibles y las comparo con los resultados obtenidos
print(f"Total posible: {combinaciones_totales}, con datos: {len(resultados)}, sin datos: {combinaciones_totales - len(resultados)}")
# Out:
# Total posible: 408, con datos: 243, sin datos: 165

# %%
resultados = [] #ciclo para recorrer por segunda vez los meses y sustancias, pero ahora guardando un log de lo que se va haciendo y si hubo error o no
log = [] 

for mes in meses:
    for sustancia in sustancias:
        resource_id = f"EPD_SNOMED_{mes}"
        sql = f"""SELECT * FROM `{resource_id}` where CHEMICAL_SUBSTANCE_BNF_DESCR = '{sustancia}'"""
        
        entrada = {'mes': mes, 'sustancia': sustancia}  
        
        try:
            r = requests.get(BASE_URL, params={'resource_id': resource_id, 'sql': sql}, timeout=60)
            j = r.json()
            
            if r.status_code == 200 and 'error' not in j:         
                records = extraer_records(j)
                if records:
                    df = pd.DataFrame(records)
                    resultados.append(df)
                    entrada['status'] = 'ok'
                    entrada['filas'] = len(records)
                else:
                    entrada['status'] = 'zero'         # cero real, confirmado sin error
            else:
                entrada['status'] = 'error'                
                entrada['detalle'] = j.get('error')
        except Exception as e:
            entrada['status'] = 'error'
            entrada['detalle'] = str(e)
        
        log.append(entrada)
        print(mes, sustancia, entrada['status'])
        time.sleep(0.3)
# Out:
# 202101 Semaglutide ok
# 202101 Liraglutide ok
# 202101 Dulaglutide ok
# 202101 Exenatide ok
# 202101 Lixisenatide ok
# 202101 Tirzepatide zero
# 202102 Semaglutide ok
# 202102 Liraglutide ok
# 202102 Dulaglutide ok
# 202102 Exenatide ok
# 202102 Lixisenatide ok
# 202102 Tirzepatide zero
# 202103 Semaglutide ok
# 202103 Liraglutide ok
# 202103 Dulaglutide ok
# 202103 Exenatide ok
# 202103 Lixisenatide ok
# 202103 Tirzepatide zero
# 202104 Semaglutide ok
# 202104 Liraglutide ok
# 202104 Dulaglutide ok
# 202104 Exenatide ok
# 202104 Lixisenatide ok
# 202104 Tirzepatide zero
# 202105 Semaglutide ok
# 202105 Liraglutide ok
# 202511 Tirzepatide error
# 202512 Semaglutide error
# 202512 Liraglutide error
# 202512 Dulaglutide error
# 202512 Exenatide error
# 202512 Lixisenatide error
# 202512 Tirzepatide error
# 202601 Semaglutide error
# 202601 Liraglutide error
# 202601 Dulaglutide error
# 202601 Exenatide error
# 202601 Lixisenatide error
# 202601 Tirzepatide error
# 202602 Semaglutide error
# 202602 Liraglutide error
# 202602 Dulaglutide error
# 202602 Exenatide error
# 202602 Lixisenatide error
# 202602 Tirzepatide error
# 202603 Semaglutide error
# 202603 Liraglutide error
# 202603 Dulaglutide error
# 202603 Exenatide error
# 202603 Lixisenatide error
# 202603 Tirzepatide error
# 202604 Semaglutide error
# 202604 Liraglutide error
# 202604 Dulaglutide error
# 202604 Exenatide error
# 202604 Lixisenatide error
# 202604 Tirzepatide error
# 202605 Semaglutide error
# 202605 Liraglutide error
# 202605 Dulaglutide error
# 202605 Exenatide error
# 202605 Lixisenatide error
# 202605 Tirzepatide error
# 202606 Semaglutide error
# 202606 Liraglutide error
# 202606 Dulaglutide error
# 202606 Exenatide error
# 202606 Lixisenatide error
# 202606 Tirzepatide error
# 202607 Semaglutide error
# 202607 Liraglutide error
# 202607 Dulaglutide error
# 202607 Exenatide error
# 202607 Lixisenatide error
# 202607 Tirzepatide error
# 202608 Semaglutide error
# 202608 Liraglutide error
# 202608 Dulaglutide error
# 202608 Exenatide error
# 202608 Lixisenatide error
# 202608 Tirzepatide error

# %%
mes = "202303"  # uno de los meses que salió "zero"
sustancia = "Semaglutide"
resource_id = f"EPD_SNOMED_{mes}"
sql = f"""SELECT * FROM `{resource_id}` where CHEMICAL_SUBSTANCE_BNF_DESCR = '{sustancia}' LIMIT 100"""

r = requests.get(BASE_URL, params={'resource_id': resource_id, 'sql': sql}, timeout=60)
j =r.json()
print('HTTP status:', r.status_code)
print('Registros devueltos:', len(extraer_records(j)))
#prueba porque no me trae registros, aunque en la API sí hay registros para ese mes y sustancia.
# Out:
# HTTP status: 200
# Registros devueltos: 100

# %%
mes = "202503"
sustancia = "Semaglutide"
resource_id = f"EPD_SNOMED_{mes}"
sql = f"""SELECT * FROM `{resource_id}` where CHEMICAL_SUBSTANCE_BNF_DESCR = '{sustancia}' LIMIT 5"""
r = requests.get(BASE_URL, params={'resource_id': resource_id, 'sql': sql}, timeout=60)
j =r.json()
print('HTTP status:', r.status_code)
print('Registros devueltos:', len(extraer_records(j)))
#era demasiada información, por lo que le puse un límite de 5 registros y ahora sí me trae registros.
# Out:
# HTTP status: 500
# Registros devueltos: 0

# %%
def columna_sustancia(mes):
    if mes >= "202503":  
        return "BNF_CHEMICAL_SUBSTANCE"
    else:
        return "CHEMICAL_SUBSTANCE_BNF_DESCR"

   #noté que la columna que contiene la sustancia cambia a partir de marzo 2025, por lo que hice una función para determinar qué columna usar según el mes.

# %%
#aquí hago un ciclo para reintentar los errores que se registraron en el log, usando la función columna_sustancia() para determinar qué columna usar según el mes.
errores = [e for e in log if e['status'] == 'error']
print(f"Total a reintentar: {len(errores)}")

for entrada in errores:
    mes = entrada['mes']
    sustancia = entrada['sustancia']                          
    resource_id = f"EPD_SNOMED_{mes}"
    columna = columna_sustancia(mes)                             
    
    sql = f"""SELECT * FROM `{resource_id}` where {columna} = '{sustancia}'"""
    
    try:
        r = requests.get(BASE_URL, params={'resource_id': resource_id, 'sql': sql}, timeout=60)
        j = r.json()
        
        if r.status_code == 200 and 'error' not in j:
            records = extraer_records(j)
            if records:
                df = pd.DataFrame(records)
                resultados.append(df)
                entrada['status'] = 'ok'          # actualizamos el log, ya no es error
                entrada['filas'] = len(records)
            else:
                entrada['status'] = 'zero'
        else:
            entrada['detalle'] = j.get('error')   # seguirá en 'error' si vuelve a fallar
    except Exception as e:
        entrada['detalle'] = str(e)
    
    print(mes, sustancia, entrada['status'])
    time.sleep(0.3)
# Out:
# Total a reintentar: 108
# 202503 Semaglutide zero
# 202503 Liraglutide ok
# 202503 Dulaglutide ok
# 202503 Exenatide ok
# 202503 Lixisenatide ok
# 202503 Tirzepatide zero
# 202504 Semaglutide zero
# 202504 Liraglutide ok
# 202504 Dulaglutide ok
# 202504 Exenatide ok
# 202504 Lixisenatide ok
# 202504 Tirzepatide zero
# 202505 Semaglutide zero
# 202505 Liraglutide ok
# 202505 Dulaglutide ok
# 202505 Exenatide ok
# 202505 Lixisenatide ok
# 202505 Tirzepatide zero
# 202506 Semaglutide zero
# 202506 Liraglutide ok
# 202506 Dulaglutide ok
# 202506 Exenatide ok
# 202506 Lixisenatide ok
# 202506 Tirzepatide zero
# 202507 Semaglutide zero
# 202507 Liraglutide ok
# 202507 Dulaglutide ok
# 202507 Exenatide ok
# 202507 Lixisenatide ok
# 202507 Tirzepatide zero
# 202508 Semaglutide zero
# 202508 Liraglutide ok
# 202508 Dulaglutide ok
# 202508 Exenatide ok
# 202508 Lixisenatide ok
# 202508 Tirzepatide zero
# 202509 Semaglutide zero
# 202509 Liraglutide ok
# 202509 Dulaglutide ok
# 202509 Exenatide ok
# 202509 Lixisenatide ok
# 202509 Tirzepatide zero
# 202510 Semaglutide zero
# 202510 Liraglutide ok
# 202510 Dulaglutide ok
# 202510 Exenatide ok
# 202510 Lixisenatide ok
# 202510 Tirzepatide zero
# 202511 Semaglutide zero
# 202511 Liraglutide ok
# 202511 Dulaglutide ok
# 202511 Exenatide ok
# 202511 Lixisenatide ok
# 202511 Tirzepatide zero
# 202512 Semaglutide zero
# 202512 Liraglutide ok
# 202512 Dulaglutide ok
# 202512 Exenatide ok
# 202512 Lixisenatide ok
# 202512 Tirzepatide zero
# 202601 Semaglutide zero
# 202601 Liraglutide ok
# 202601 Dulaglutide ok
# 202601 Exenatide ok
# 202601 Lixisenatide zero
# 202601 Tirzepatide zero
# 202602 Semaglutide zero
# 202602 Liraglutide ok
# 202602 Dulaglutide ok
# 202602 Exenatide ok
# 202602 Lixisenatide zero
# 202602 Tirzepatide zero
# 202603 Semaglutide zero
# 202603 Liraglutide ok
# 202603 Dulaglutide ok
# 202603 Exenatide ok
# 202603 Lixisenatide zero
# 202603 Tirzepatide zero
# 202604 Semaglutide zero
# 202604 Liraglutide ok
# 202604 Dulaglutide ok
# 202604 Exenatide ok
# 202604 Lixisenatide zero
# 202604 Tirzepatide zero
# 202605 Semaglutide zero
# 202605 Liraglutide ok
# 202605 Dulaglutide ok
# 202605 Exenatide ok
# 202605 Lixisenatide zero
# 202605 Tirzepatide zero
# 202606 Semaglutide error
# 202606 Liraglutide error
# 202606 Dulaglutide error
# 202606 Exenatide error
# 202606 Lixisenatide error
# 202606 Tirzepatide error
# 202607 Semaglutide error
# 202607 Liraglutide error
# 202607 Dulaglutide error
# 202607 Exenatide error
# 202607 Lixisenatide error
# 202607 Tirzepatide error
# 202608 Semaglutide error
# 202608 Liraglutide error
# 202608 Dulaglutide error
# 202608 Exenatide error
# 202608 Lixisenatide error
# 202608 Tirzepatide error

# %%
[e for e in log if e['mes'] == '202606' and e['sustancia'] == 'Semaglutide']
#noto que alguno no están porque es informacion muy reciente y la API no tiene información de ese mes, por lo que no hay registros para esa combinación de mes y sustancia.
# Out:
# [{'mes': '202606',
#   'sustancia': 'Semaglutide',
#   'status': 'error',
#   'detalle': {'__type': 'Not Found Error', 'message': 'Not found'}}]

# %%
#hago una función para traer los registros de manera paginada, ya que la API tiene un límite de 1000 registros por consulta y algunas combinaciones de mes y sustancia tienen más de 1000 registros.
def traer_paginado(resource_id, columna, sustancia, tamano_pagina=1000):
    todas = []
    offset = 0
    while True:
        sql = f"""SELECT * FROM `{resource_id}` where {columna} = '{sustancia}' LIMIT {tamano_pagina} OFFSET {offset}"""
        r = requests.get(BASE_URL, params={'resource_id': resource_id, 'sql': sql}, timeout=60)
        j = r.json()
        records = extraer_records(j)
        
        if not records:
            break                       # ya no hay más páginas
        
        todas.extend(records)
        
        if len(records) < tamano_pagina:
            break                       
        
        offset += tamano_pagina                    
        time.sleep(0.3)
    
    return todas

# %%
errores_restantes = [e for e in log if e['status'] == 'error']
for e in errores_restantes:
    print(e['mes'], e['sustancia'], e.get('detalle'))
    #estos son todos los que siguen con error, ya que la API no tiene información de ese mes y sustancia, por lo que no hay registros para esa combinación.
# Out:
# 202606 Semaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202606 Liraglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202606 Dulaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202606 Exenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202606 Lixisenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202606 Tirzepatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Semaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Liraglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Dulaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Exenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Lixisenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202607 Tirzepatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Semaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Liraglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Dulaglutide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Exenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Lixisenatide {'__type': 'Not Found Error', 'message': 'Not found'}
# 202608 Tirzepatide {'__type': 'Not Found Error', 'message': 'Not found'}

# %%
#extraigo los registros de las combinaciones que salieron como "zero" en el log, usando la función traer_paginado() para traer todos los registros de manera paginada.
zeros = [e for e in log if e['status'] == 'zero']
print(f"Total a revisar: {len(zeros)}")

for entrada in zeros:
    mes = entrada['mes']
    sustancia = entrada['sustancia']                                
    resource_id = f"EPD_SNOMED_{mes}"
    columna = columna_sustancia(mes)                                 

    records = traer_paginado(resource_id, columna, sustancia)

    if records:
        df = pd.DataFrame(records)
        resultados.append(df)
        entrada['status'] = 'ok'
        entrada['filas'] = len(records)
        print(mes, sustancia, '-> recuperado:', len(records))
    else:
        print(mes, sustancia, '-> cero confirmado')
ignore_index=True)
#
# NameError: name 'pd' is not defined

# %%
df_final.to_csv("glp1_crudo.csv", index=False) #lo guardo en un archivo CSV para poder trabajar con él después sin tener que volver a hacer todas las consultas a la API.

# %%
print(df_final.shape) #son aproximadamente 1.5 millones de registros, por lo que es un archivo grande, pero manejable en memoria.
# Out:
# (5130929, 33)

# %%
print(df_final.iloc[0]['BNF_CHEMICAL_SUBSTANCE'])      # una fila de los primeros meses
print(df_final.iloc[-1]['BNF_CHEMICAL_SUBSTANCE'])      # una fila de los últimos meses
#DETECTANDO LOS ASPECTOS EN QUE HAY QUE HACER LIMPIEZA DE DATOS, YA QUE HAY REGISTROS QUE NO SON RELEVANTES PARA EL ANÁLISIS, COMO LOS QUE TIENEN CERO PRESCRIPCIONES O CERO COSTO.
# Out:
# 0601023AW
# Tirzepatide

# %%
pd.DataFrame(log).to_csv("log_extraccion.csv", index=False)
#Guardo el log de la extracción en un archivo CSV para poder revisarlo después y ver qué combinaciones de mes y sustancia tuvieron errores o cero registros.

# %% [markdown]
# ##LIMPIEZA DE DATOS

# %%
import pandas as pd

df_final = pd.read_csv("glp1_crudo.csv")
print(df_final.shape)
# Out:
# C:\Users\esmeg\AppData\Local\Temp\ipykernel_34004\3996952778.py:3: DtypeWarning: Columns (0,3,4,15,16,17,27,28,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_final = pd.read_csv("glp1_crudo.csv")
# (5130929, 33)

# %%
print(df_final.iloc[0]['YEAR_MONTH'], type(df_final.iloc[0]['YEAR_MONTH']))
print(df_final.iloc[-1]['YEAR_MONTH'], type(df_final.iloc[-1]['YEAR_MONTH']))
#se oupa ajustar tipo de dato en la columna YEAR_MONTH, ya que es un string y debería ser un entero para poder hacer análisis de series de tiempo.
# Out:
# 202101 <class 'int'>
# 2026-05 <class 'str'>

# %%
year_month_texto = df_final['YEAR_MONTH'].astype(str)
year_month_limpio = year_month_texto.str.replace('-', '')  
df_final['FECHA'] = pd.to_datetime(year_month_limpio, format='%Y%m')

# %%
print(df_final['FECHA'].min(), df_final['FECHA'].max())
print(df_final['FECHA'].isnull().sum())
#fecha arreglada, ya que ahora es un objeto datetime y se puede usar para análisis de series de tiempo.
# Out:
# 2021-01-01 00:00:00 2026-05-01 00:00:00
# 0

# %%
import numpy as np

corte = pd.Timestamp('2025-03-01')

df_final['SUSTANCIA'] = np.where(
    df_final['FECHA'] < corte,
    df_final['CHEMICAL_SUBSTANCE_BNF_DESCR'],
    df_final['BNF_CHEMICAL_SUBSTANCE']                           
)

#Hay un problema con la columna SUSTANCIA, ya que a partir de marzo 2025 la columna que contiene el nombre de la sustancia cambia de CHEMICAL_SUBSTANCE_BNF_DESCR a BNF_CHEMICAL_SUBSTANCE, por lo que hay que hacer un ajuste para que todas las filas tengan el nombre de la sustancia en la misma columna.

# %%
print(df_final[df_final['FECHA'] < corte]['SUSTANCIA'].unique())
print(df_final[df_final['FECHA'] >= corte]['SUSTANCIA'].unique())
#olumna de sustancia ya arreglada, ya que ahora todas las filas tienen el nombre de la sustancia en la misma columna, independientemente de la fecha.
# Out:
# ['Semaglutide' 'Liraglutide' 'Dulaglutide' 'Exenatide' 'Lixisenatide'
#  'Tirzepatide']
# ['Liraglutide' 'Dulaglutide' 'Exenatide' 'Lixisenatide' 'Semaglutide'
#  'Tirzepatide']

# %%
df_final['PRESENTACION'] = np.where(
    df_final['FECHA'] < corte,
    df_final['BNF_DESCRIPTION'],    
    df_final['BNF_PRESENTATION_NAME']    
)
#la Columna de presentación también tiene el mismo problema que la columna de sustancia, por lo que se hace el mismo ajuste para que todas las filas tengan el nombre de la presentación en la misma columna.

# %%
print(df_final[df_final['FECHA'] < corte]['PRESENTACION'].unique()[:5])
print(df_final[df_final['FECHA'] >= corte]['PRESENTACION'].unique()[:5])
# Out:
# ['Semaglutide 7mg tablets'
#  'Semaglutide 0.5mg/0.37ml inj 1.5ml pf dispos dev'
#  'Semaglutide 3mg tablets' 'Ozempic 1mg/0.74ml inj 3ml pre-filled pens'
#  'Semaglutide 0.25mg/0.19ml inj 1.5ml pf dispos dev']
# ['Diavic 6mg/ml solution for injection 3ml pre-filled pens'
#  'Liraglutide 6mg/1ml inj 3ml pre-filled disposable devices'
#  'Victoza 6mg/ml solution for injection 3ml pre-filled pens'
#  'Saxenda 6mg/ml solution for injection 3ml pre-filled pens'
#  'Zegluxen 6mg/ml solution for injection 3ml pre-filled pens']

# %%
df_final['REGION_NAME'] = np.where(
    df_final['FECHA'] < corte,
    df_final['STP_NAME'],    
    df_final['ICB_NAME']    
)
#la columna de región también tiene el mismo problema que las columnas de sustancia y presentación, por lo que se hace el mismo ajuste para que todas las filas tengan el nombre de la región en la misma columna.

df_final['ADQ_USAGE'] = np.where(
    df_final['FECHA'] < corte,
    df_final['ADQUSAGE'],    
    df_final['ADQ_USAGE']    
)
#la columna de ADQ_USAGE también tiene el mismo problema que las columnas de sustancia, presentación y región, por lo que se hace el mismo ajuste para que todas las filas tengan el valor de ADQ_USAGE en la misma columna.

# %%
print(df_final[df_final['FECHA'] < corte]['REGION_NAME'].unique()[:5])
print(df_final[df_final['FECHA'] >= corte]['REGION_NAME'].unique()[:5])

print(df_final['ADQ_USAGE'].describe())
# Out:
# ['CUMBRIA & NORTH EAST STP' 'NW LONDON HEALTH & CARE PARTNERSHIP STP'
#  'MID AND SOUTH ESSEX STP' 'CHESHIRE & MERSEYSIDE STP'
#  'HUMBER, COAST & VALE STP']
# ['NHS BUCKINGHAMSHIRE, OXFORDSHIRE AND BERKSHIRE WEST INTEGRATED CARE BOARD'
#  'NHS DERBY AND DERBYSHIRE INTEGRATED CARE BOARD'
#  'NHS HUMBER AND NORTH YORKSHIRE INTEGRATED CARE BOARD'
#  'NHS BLACK COUNTRY INTEGRATED CARE BOARD'
#  'NHS NORTH CENTRAL LONDON INTEGRATED CARE BOARD']
# count    5.130929e+06
# mean     3.344454e+01
# std      2.553991e+02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      5.270720e+04
# Name: ADQ_USAGE, dtype: float64

# %%
print(df_final['BNF_CHAPTER_PLUS_CODE'].unique())
#se va a eliminar porque no es relevante parab el análisis, ya que todos los registros son de GLP-1 y no hay variación en esta columna.
# Out:
# ['06: Endocrine System']

# %%
columnas_a_eliminar = [
    'YEAR_MONTH', 'STP_NAME', 'STP_CODE', 'ICB_NAME', 'ICB_CODE',
    'CHEMICAL_SUBSTANCE_BNF_DESCR', 'BNF_CHEMICAL_SUBSTANCE', 'BNF_CHEMICAL_SUBSTANCE_CODE',
    'BNF_CODE', 'BNF_DESCRIPTION', 'BNF_PRESENTATION_CODE', 'BNF_PRESENTATION_NAME',
    'ADQUSAGE', 'BNF_CHAPTER_PLUS_CODE',
    'PCO_NAME', 'PCO_CODE', 'REGIONAL_OFFICE_CODE',
    'ADDRESS_1', 'ADDRESS_2', 'ADDRESS_3', 'ADDRESS_4', 'SNOMED_CODE'
]

df_final = df_final.drop(columns=columnas_a_eliminar)
#eliminar columnas que no son relevantes para el análisis

# %%
print(df_final.columns.tolist())
print(df_final.shape)
#olumnas finales y forma del dataframe después de la limpieza de datos, ya que se eliminaron columnas que no son relevantes para el análisis.
# Out:
# ['REGIONAL_OFFICE_NAME', 'PRACTICE_NAME', 'PRACTICE_CODE', 'POSTCODE', 'QUANTITY', 'ITEMS', 'TOTAL_QUANTITY', 'NIC', 'ACTUAL_COST', 'UNIDENTIFIED', 'ADQ_USAGE', 'FECHA', 'SUSTANCIA', 'PRESENTACION', 'REGION_NAME']
# (5130929, 15)

# %%
#Buscar valores raros en columnas
columnas_texto = ['REGIONAL_OFFICE_NAME', 'PRACTICE_NAME', 'PRACTICE_CODE', 
                   'POSTCODE', 'SUSTANCIA', 'PRESENTACION', 'REGION_NAME', 'UNIDENTIFIED']

for columna in columnas_texto:
    print(f"--- {columna} ---")
    print(df_final[columna].value_counts().head(10)) 
    print()
# Out:
# --- REGIONAL_OFFICE_NAME ---
# REGIONAL_OFFICE_NAME
# MIDLANDS                    1048780
# NORTH WEST                   816796
# LONDON                       816461
# SOUTH EAST                   766714
# NORTH EAST AND YORKSHIRE     712720
# EAST OF ENGLAND              527252
# SOUTH WEST                   441094
# UNIDENTIFIED                   1112
# Name: count, dtype: int64
#
# --- PRACTICE_NAME ---
# PRACTICE_NAME
# PARK SURGERY                7063
# RIVERSIDE SURGERY           6844
# CENTRAL SURGERY             5399
# HIGH STREET SURGERY         5224
# VILLAGE SURGERY             5117
# TRINITY MEDICAL CENTRE      4401
# THE LIMES MEDICAL CENTRE    4381
# ORCHARD SURGERY             4101
# THE ELMS MEDICAL CENTRE     4092
# THE VILLAGE SURGERY         3929
# Name: count, dtype: int64
#
# --- PRACTICE_CODE ---
# PRACTICE_CODE
# F85002    3291
# M92612    2683
# P88026    2666
# J82069    2638
# P83012    2499
# M81026    2477
# G85034    2434
# J82622    2433
# M92011    2370
# J82134    2370
# Name: count, dtype: int64
#
# --- POSTCODE ---
# POSTCODE
# SK11 6JL    5800
# WS3 3JP     4744
# N9 7HD      4537
# BB9 7SR     4233
# GL50 4DP    4012
# HA0 4UZ     3849
# N9 0TW      3721
# B70 7AW     3630
# WV13 2DR    3538
# B21 9RY     3472
# Name: count, dtype: int64
#
# --- SUSTANCIA ---
# SUSTANCIA
# Semaglutide     2104142
# Dulaglutide     1392705
# Tirzepatide      907172
# Liraglutide      531036
# Exenatide        157866
# Lixisenatide      38008
# Name: count, dtype: int64
#
# --- PRESENTACION ---
# PRESENTACION
# Trulicity 1.5mg/0.5ml solution for injection pre-filled pens    426805
# Ozempic 1mg/0.74ml inj 3ml pre-filled pens                      399399
# Victoza 6mg/ml solution for injection 3ml pre-filled pens       271004
# Ozempic 0.5mg/0.37ml inj 1.5ml pre-filled pens                  267410
# Trulicity 3mg/0.5ml solution for injection pre-filled pens      245220
# Liraglutide 6mg/1ml inj 3ml pre-filled disposable devices       242063
# Dulaglutide 1.5mg/0.5ml inj pre-filled disposable devices       234143
# Trulicity 0.75mg/0.5ml inj pre-filled pens                      174454
# Rybelsus 7mg tablets                                            166656
# Mounjaro KwikPen 5mg/0.6ml inj 2.4ml pre-filled pens            158431
# Name: count, dtype: int64
#
# --- REGION_NAME ---
# REGION_NAME
# NHS GREATER MANCHESTER INTEGRATED CARE BOARD              110494
# NHS CHESHIRE AND MERSEYSIDE INTEGRATED CARE BOARD          87321
# NHS NORTH EAST AND NORTH CUMBRIA INTEGRATED CARE BOARD     79924
# GREATER MANCHESTER HSC PARTNERSHIP STP                     67272
# NHS NORTH WEST LONDON INTEGRATED CARE BOARD                64719
# NHS NORTH EAST LONDON INTEGRATED CARE BOARD                63548
# NHS WEST YORKSHIRE INTEGRATED CARE BOARD                   56431
# NHS KENT AND MEDWAY INTEGRATED CARE BOARD                  53765
# NHS LANCASHIRE AND SOUTH CUMBRIA INTEGRATED CARE BOARD     53605
# CHESHIRE & MERSEYSIDE STP                                  51553
# Name: count, dtype: int64
#
# --- UNIDENTIFIED ---
# UNIDENTIFIED
# N    5128332
# Y       2597
# Name: count, dtype: int64

# %%
mascara = df_final['PRACTICE_NAME'] == '-'
print(mascara.sum())

mascara = df_final['PRACTICE_CODE'] == '-'
print(mascara.sum())

mascara = df_final['POSTCODE'] == '-'
print(mascara.sum())
# Out:
# 0
# 1112
# 1112

# %%
mascara = df_final['PRACTICE_NAME'] == 'UNIDENTIFIED DOCTORS'
print(mascara.sum())

combinado = (df_final['PRACTICE_CODE'] == '-') & (df_final['REGIONAL_OFFICE_NAME'] == 'UNIDENTIFIED')
print(combinado.sum())

combinado2 = combinado & (df_final['UNIDENTIFIED'] == 'Y')
print(combinado2.sum())
# Out:
# 2597
# 1112
# 1112

# %%
grupo_grande = df_final['PRACTICE_NAME'] == 'UNIDENTIFIED DOCTORS'
grupo_chico = (df_final['PRACTICE_CODE'] == '-') & (df_final['REGIONAL_OFFICE_NAME'] == 'UNIDENTIFIED')

print('Grande:', grupo_grande.sum())
print('Chico:', grupo_chico.sum())
print('Ambos a la vez:', (grupo_grande & grupo_chico).sum())
#Hay un grupo grande de registros que tienen PRACTICE_NAME = 'UNIDENTIFIED DOCTORS' y un grupo chico que tiene PRACTICE_CODE = '-' y REGIONAL_OFFICE_NAME = 'UNIDENTIFIED', pero no son los mismos registros, por lo que se van a eliminar.
# Out:
# Grande: 2597
# Chico: 1112
# Ambos a la vez: 1112

# %%
df_final = df_final[~grupo_grande]
#conservar solo los registros que no están en el grupo grande, ya que son los que tienen información relevante para el análisis.

# %%
print(df_final.dtypes)
#los tipos de datos de las columnas son correctos, ya que las columnas numéricas son de tipo float64 y las columnas de texto son de tipo object.
# Out:
# REGIONAL_OFFICE_NAME            object
# PRACTICE_NAME                   object
# PRACTICE_CODE                   object
# POSTCODE                        object
# QUANTITY                         int64
# ITEMS                            int64
# TOTAL_QUANTITY                   int64
# NIC                            float64
# ACTUAL_COST                    float64
# UNIDENTIFIED                    object
# ADQ_USAGE                      float64
# FECHA                   datetime64[ns]
# SUSTANCIA                       object
# PRESENTACION                    object
# REGION_NAME                     object
# dtype: object

# %%
#revisar si hay duplicados
duplicados = df_final.duplicated()
print(duplicados.sum())
# Out:
# 779589

# %%
filas_duplicadas = df_final[df_final.duplicated(keep=False)]
print(filas_duplicadas['SUSTANCIA'].value_counts())
#se van a eliminar los duplicados, ya que no son relevantes para el análisis y solo ocupan espacio en memoria.
# Out:
# SUSTANCIA
# Semaglutide    938105
# Tirzepatide    439093
# Name: count, dtype: int64

# %%
df_final = df_final.drop_duplicates()

# %%
print(df_final.shape)
print(df_final.duplicated().sum())
# Out:
# (4348743, 15)
# 0

# %%
print(df_final.isnull().sum())
#nulos
# Out:
# REGIONAL_OFFICE_NAME          0
# PRACTICE_NAME                 0
# PRACTICE_CODE                 0
# POSTCODE                   2123
# QUANTITY                      0
# ITEMS                         0
# TOTAL_QUANTITY                0
# NIC                           0
# ACTUAL_COST                   0
# UNIDENTIFIED                  0
# ADQ_USAGE                     0
# FECHA                         0
# SUSTANCIA                     0
# PRESENTACION                  0
# REGION_NAME             2280653
# dtype: int64

# %%
#sanidad en numericas
print(df_final[['QUANTITY', 'ITEMS', 'TOTAL_QUANTITY', 'NIC', 'ACTUAL_COST', 'ADQ_USAGE']].describe())
# Out:
#            QUANTITY         ITEMS  TOTAL_QUANTITY           NIC   ACTUAL_COST  \
# count  4.348743e+06  4.348743e+06    4.348743e+06  4.348743e+06  4.348743e+06
# mean   7.767603e+00  3.366831e+00    2.115341e+01  3.618914e+02  3.509270e+02
# std    1.317879e+01  5.606969e+00    5.665887e+01  7.308014e+02  7.223100e+02
# min    0.000000e+00  1.000000e+00    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    1.000000e+00  1.000000e+00    3.000000e+00  8.189000e+01  7.849240e+01
# 50%    4.000000e+00  2.000000e+00    6.000000e+00  1.569600e+02  1.569724e+02
# 75%    4.000000e+00  3.000000e+00    1.600000e+01  3.600000e+02  3.409494e+02
# max    9.300000e+02  3.180000e+02    4.020000e+03  5.724000e+04  5.646307e+04
#
#           ADQ_USAGE
# count  4.348743e+06
# mean   3.945402e+01
# std    2.769858e+02
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    5.270720e+04

# %%
df_final['REGION_NAME'] = df_final['REGION_NAME'].fillna('No disponible')
#nulos en REGION_NAME reemplazados por 'No disponible', ya que es una columna de texto y no se puede dejar con valores nulos para el análisis.

# %%
df_final['POSTCODE'] = df_final['POSTCODE'].fillna('SIN_CP')
#NULOS en postcode reemplazados por 'SIN_CP', ya que es una columna de texto y no se puede dejar con valores nulos para el análisis.

# %%
df_final.to_csv("glp1_limpio.csv", index=False)

# %%
import os
print('Crudo:', os.path.getsize("glp1_crudo.csv") / (1024*1024), 'MB')
print('Limpio:', os.path.getsize("glp1_limpio.csv") / (1024*1024), 'MB')
# Out:
# Crudo: 1793.4788265228271 MB
# Limpio: 748.3355197906494 MB

# %%
df_final.head(10000).to_csv("glp1_muestra.csv", index=False)
